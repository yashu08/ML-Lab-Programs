# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/yashaswini/Downloads/Sales.csv")

# %%
data.head()
# Out:
#    SL NO  WEEK  SALES
# 0      1     1   1200
# 1      2     2   1800
# 2      3     3   2600
# 3      4     4   3200
# 4      5     5   3800

# %%
data.shape
# Out:
# (5, 3)

# %%
data.isna().sum()
# Out:
# SL NO    0
# WEEK     0
# SALES    0
# dtype: int64

# %%
data.duplicated().any()
# Out:
# False

# %%
fig, axs = plt.subplots(2, figsize=(4, 5))
sns.boxplot(data['WEEK'], ax=axs[0])
sns.boxplot(data['SALES'], ax=axs[1])
plt.tight_layout()
plt.show()

# %%
sns.distplot(data['SALES'])
plt.show()
# Out:
# C:\Users\yashaswini\AppData\Local\Temp\ipykernel_6508\2407181307.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['SALES'])

# %%
sns.pairplot(data, x_vars=['WEEK'], y_vars='SALES', height=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.heatmap(data.corr(), annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
X = data[['WEEK']]
y = data['SALES']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# %%
linear_regressor = LinearRegression()
linear_regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Intercept: ', linear_regressor.intercept_)
print('Coefficient:', linear_regressor.coef_)
# Out:
# Intercept:  542.8571428571429
# Coefficient: [657.14285714]

# %%
# Displaying the regression equation
print('Regression Equation: Sales = 456.45 + 445.44 * WEEK')
# Out:
# Regression Equation: Sales = 456.45 + 445.44 * WEEK

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,657.14+ 542.857 * X_train, 'r')
